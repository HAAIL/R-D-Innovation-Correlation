# %%
import re
import matplotlib.pyplot as plt
import requests
import json
import urllib3
import string

import nltk
from nltk.tokenize import sent_tokenize
from bs4 import BeautifulSoup
# !pip install openai

import openai
nltk.download('punkt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import urllib3
#       6 import string
# ----> 8 import nltk
#       9 from nltk.tokenize import sent_tokenize
#      10 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'nltk'

# %%
#year 2021
filename2021 = "microsoft_response2021.txt"
with open(filename2021, 'r') as file:
    text = file.read()

# Extracting the topics from the text
topics = re.findall(r'\d+\. (.+)', text)
print(topics)
# Out:
# ['Delegating authorization', 'Access control', 'Data isolation', 'Resource identifiers', 'Remote data repositories', 'Authorization indication', 'Access prohibition1. Video encoding', 'Video decoding', 'Latency reduction techniques', 'Frame reordering', 'Real-time communication', 'Syntax elements', 'Inter-frame dependencies', 'Video sequence', 'Reconstructed frames', 'Output order1. Zoned time-of-flight (ToF) arrangement', 'Sensor', 'Steerable light source', 'Illumination beam', 'Angular extent', 'Field of view (FoV)', 'Region of interest', 'Depth map', 'Ambient performance', 'Maximum range', 'Jitter', 'Steering alternative configurations', 'Mechanical solution', 'Electro optical solution', 'Electrowetting solution1. Privileged identity management system', 'Method for managing privileged identities', 'Requesting elevated privileges', 'Computing systems and software applications', 'Extending elevated privileges', 'Accessing privileged features', 'Performing tasks with elevated privile
# ...

# %%
# Set up OpenAI API credentials
openai.api_key = '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'

company_name = "Microsoft"  # Replace with the desired company name


def group_Topics():
    #prompt = f"Using following text find additional information regarding research information of the '{company_name}', company, provided in: {truncated_sentence}. Provide sources of the new information"
    research_info = []

    prompt = f""""Could you please categorize the following topics into major groups based on their themes?
    Your goal is to group related topics together. Here is the list of topics: {topics}
    """
    # Generate research-related information using GPT-3.5
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages = [{"role": "user", 
          "content" : prompt}],
        max_tokens=5000,  # Adjust the max_tokens value as needed
        temperature=0.7,
        n=1,
        stop=None,
    )

    # Extract the generated research-related information
    generated_text = response['choices'][0]["message"]["content"]
#     print(response)
    # Append the generated information to the research_info list
    research_info.append(generated_text)

    # Print the research-related information for each sentence
    for i, info in enumerate(research_info):
        print(f"Research information for sentence {i+1}:")
        print(info)
        print()

# %%
group_Topics()
# Out:
# Research information for sentence 1:
# Based on their themes, the topics can be categorized into the following major groups:
#
# 1. Access Control and Authorization:
#    - Delegating authorization
#    - Access control
#    - Authorization indication
#    - Access prohibition
#    - Privileged identity management system
#    - Method for managing privileged identities
#    - Requesting elevated privileges
#    - Extending elevated privileges
#    - Accessing privileged features
#    - Performing tasks with elevated privileges
#    - Utilizing a different device for communications
#    - Elevated privilege-related communications
#
# 2. Video Encoding and Decoding:
#    - Video encoding
#    - Video decoding
#    - Latency reduction techniques
#    - Frame reordering
#    - Real-time communication
#    - Syntax elements
#    - Inter-frame dependencies
#    - Video sequence
#    - Reconstructed frames
#    - Output order
#    - Video codec
#    - Quantization step size
# ...
